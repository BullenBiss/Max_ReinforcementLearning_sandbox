# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
reward_matrix = np.load('../Reward_log.npy')
cumulative_array = np.cumsum(reward_matrix)
cumulative_array
# Out:
# array([-1.00000000e+02, -2.00000000e+02, -3.00000000e+02, ...,
#        -5.05824304e+07, -5.05825304e+07, -5.05826304e+07])

# %%
plt.scatter(range(0, cumulative_array.size),cumulative_array)
plt.show()
