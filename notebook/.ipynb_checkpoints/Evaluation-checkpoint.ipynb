# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
reward_matrix = np.load('../Reward_log.npy')
cumulative_array = np.cumsum(reward_matrix)
cumulative_array
# Out:
# array([ 1.00000000e+02,  0.00000000e+00, -1.00000000e+02, ...,
#        -7.33392559e+05, -7.33492559e+05, -7.33592559e+05])

# %%
plt.scatter(range(0, cumulative_array.size),cumulative_array)
plt.show()
